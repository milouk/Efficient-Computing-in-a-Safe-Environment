# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
from pylab import rcParams
import matplotlib.ticker as ticker

# %%
import matplotlib.pyplot as plt

stock={"apache":2879.730, "CB memcpy":2470.385, "CB memset":2327.400, "CB mixed":2335.665, "CB read":2182.975,
       "CB write":2309.585, "OS create_files":188.245, "OS create_processes":275.330, "OS create_threads":211.320,
       "OS launch_programs":322.920, "MC add":682.755, "MC append":661.340, "MC delete":466.460, "MC get":464.350,
       "MC prepend":640.725, "MC replace":644.835, "MC set":684.005, "OS mem_alloc":192.920,
       "netperf_tcp_maerts":3290.570, "netperf_tcp_rr":3476.590, "netperf_tcp_sendfile":3515.900,
       "netperf_tcp_stream":3420.280, "netperf_udp_rr":3505.420, "netperf_udp_stream":3477.705, "nginx":1988.240,
       "aes":2397.490, "blowfish":728.490, "camellia":2181.765, "cast":721.995, "dsa":2859.605, "ecdsa":1845.370,
       "ghash":775.280, "hmac":750.455, "idea":731.780, "rc4":767.175, "rc5":754.855, "rmd160":740.150, "seed":716.755,
       "sha1":820.770, "sha256":804.640, "sha512":811.325, "whirlpool":814.340, 
       "stress_ng_cpu":2389.130, "stress_ng_fork":2507.680, "stress_ng_matrix":2594.365, "stress_ng_msg":2506.035,
       "stress_ng_sem":2156.180, "stress_ng_sock":2763.080, "stress_ng_switch":2705.380, "stress_ng_vecmath":2430.860}
meltdown_ondemand={"apache":2519.550, "CB memcpy":2373.920, "CB memset":2318.105, "CB mixed":2372.190, 
                   "CB read":2238.970, "CB write":2242.745, "OS create_files":196.995, 
                   "OS create_processes":188.645, "OS create_threads":133.930, "OS launch_programs":247.610, 
                   "MC add":719.140, "MC append":688.095, "MC delete":457.415, "MC get":454.880, 
                   "MC prepend":687.210, "MC replace":687.230, "MC set":724.170, "OS mem_alloc":186.070, 
                   "netperf_tcp_maerts":3411.830, "netperf_tcp_rr":3454.245, "netperf_tcp_sendfile":3395.815, 
                   "netperf_tcp_stream":3356.470, "netperf_udp_rr":3262.150, "netperf_udp_stream":3438.060, 
                   "nginx":1872.305, "aes":2376.640, "blowfish":703.185, "camellia":2322.765, "cast":706.000, 
                   "dsa":2816.015, "ecdsa":1814.810, "ghash":774.805, "hmac":788.045, "idea":715.850, 
                   "rc4":760.905, "rc5":745.325, "rmd160":773.575, "seed":713.250, "sha1":806.725, 
                   "sha256":801.030, "sha512":809.905, "whirlpool":813.200, 
                   "stress_ng_cpu":2393.430, "stress_ng_fork":1713.900, "stress_ng_matrix":2537.215, 
                   "stress_ng_msg":2486.080, "stress_ng_sem":2237.400, "stress_ng_sock":2727.780, 
                   "stress_ng_switch":2733.845, "stress_ng_vecmath":2432.995}
meltdown_performance={"apache":2668.035, "CB memcpy":2380.720, "CB memset":2276.785, "CB mixed":2365.130, 
                      "CB read":2236.925, "CB write":2289.760, "OS create_files":194.240, 
                      "OS create_processes":266.965, "OS create_threads":225.695, "OS launch_programs":341.240, 
                      "MC add":677.205, "MC append":635.365, "MC delete":424.170, "MC get":405.115, 
                      "MC prepend":629.230, "MC replace":623.425, "MC set":654.585, "OS mem_alloc":167.440, 
                      "netperf_tcp_maerts":3497.845, "netperf_tcp_rr":3314.800, "netperf_tcp_sendfile":3526.425, 
                      "netperf_tcp_stream":3453.070, "netperf_udp_rr":3523.705, "netperf_udp_stream":3511.870, 
                      "nginx":1809.905, "aes":2382.995, "blowfish":724.155, "camellia":2291.340, "cast":697.265, 
                      "dsa":2881.705, "ecdsa":1838.540, "ghash":734.810, "hmac":782.610, "idea":731.375, 
                      "rc4":776.615, "rc5":777.290, "rmd160":773.550, "seed":671.470, "sha1":813.670, 
                      "sha256":785.125, "sha512":821.350, "whirlpool":805.310, "stress_ng_cpu":2403.600, 
                      "stress_ng_fork":2522.255, "stress_ng_matrix":2581.440, "stress_ng_msg":2517.320, 
                      "stress_ng_sem":2226.495, "stress_ng_sock":2725.525, "stress_ng_switch":2589.450, 
                      "stress_ng_vecmath":2354.710}

plt.figure(figsize=(18,7))
plt.xticks(fontsize=13, rotation=270)
plt.yticks(fontsize=13)
plt.ylabel("Energy Consumption (in Joules)", fontsize=13) 

loc_s = np.arange(len(meltdown_performance))+0.2 # Offsetting the tick-label location
loc_r = np.arange(len(stock))-0.2 # Offsetting the tick-label location
xtick_loc = list(loc_s) + list(loc_r)
xticks = list(meltdown_ondemand.keys())

plt.bar(loc_s,list(meltdown_performance.values()),color="green", width=0.35,label='Metldown OFF')
plt.bar(loc_r,list(stock.values()),color="red", width=0.35,label='Stock')
plt.xticks(xtick_loc, xticks, rotation=90, ha="right")
plt.tick_params(axis='x', which='minor', pad=15)
plt.legend(loc='upper right', prop={'size': 15})
plt.title('CPU Governor: Performance')
plt.savefig("euro_sys/meltdown/energy_stock_meltdown_performance.pdf", bbox_inches='tight')

# %%
spectre_ondemand={"apache":2839.060, "CB memcpy":2415.510, "CB memset":2339.095, "CB mixed":2386.940, "CB read":2191.585,
         "CB write":2240.190, "OS create_files":194.825, "OS create_processes":193.705,
         "OS create_threads":152.095, "OS launch_programs":246.475, "MC add":733.685, "MC append":716.325,
         "MC delete":459.500, "MC get":449.200, "MC prepend":711.435, "MC replace":707.715, "MC set":731.680,
         "OS mem_alloc":173.805, "netperf_tcp_maerts":3440.920, "netperf_tcp_rr":3458.625,
         "netperf_tcp_sendfile":3486.755, "netperf_tcp_stream":3387.380, "netperf_udp_rr":3487.925,
         "netperf_udp_stream":3423.385, "nginx":1991.425, "aes":2398.675, "blowfish":721.135, "camellia":2327.730,
         "cast":720.010, "dsa":2778.680, "ecdsa":1852.955, "ghash":771.985, "hmac":772.150, "idea":728.300,
         "rc4":788.125, "rc5":769.395, "rmd160":773.070, "seed":735.500, "sha1":800.110, "sha256":809.040,
         "sha512":823.935, "whirlpool":816.680, "stress_ng_cpu":2399.900, "stress_ng_fork":1726.060,
         "stress_ng_matrix":2614.250, "stress_ng_msg":2467.050, "stress_ng_sem":2235.420,
         "stress_ng_sock":2731.955, "stress_ng_switch":2665.445, "stress_ng_vecmath":2384.955}

spectre_performance={"apache":2561.035, "CB memcpy":2398.450, "CB memset":2269.085, "CB mixed":2386.640, 
             "CB read":2229.440, "CB write":2313.950, "OS create_files":196.530, "OS create_processes":272.890, 
             "OS create_threads":204.965, "OS launch_programs":321.650, "MC add":541.645, "MC append":535.090, 
             "MC delete":344.655, "MC get":356.875, "MC prepend":539.360, "MC replace":546.175, "MC set":566.770, 
             "OS mem_alloc":183.705, "netperf_tcp_maerts":3481.135, "netperf_tcp_rr":3515.085, 
             "netperf_tcp_sendfile":3520.250, "netperf_tcp_stream":3434.025, "netperf_udp_rr":3329.735,
             "netperf_udp_stream":3492.800, "nginx":1684.625, "aes":2394.110, "blowfish":735.495,
             "camellia":2316.560, "cast":739.140, "dsa":2862.990, "ecdsa":1823.855, "ghash":767.920, 
             "hmac":795.500, "idea":726.955, "rc4":745.820, "rc5":776.060, "rmd160":767.755, "seed":721.180, 
             "sha1":812.785, "sha256":797.510, "sha512":834.495, "whirlpool":808.060,  
             "stress_ng_cpu":2393.560, "stress_ng_fork":2554.500, "stress_ng_matrix":2591.100, 
             "stress_ng_msg":2550.875, "stress_ng_sem":2240.245, "stress_ng_sock":2756.945, 
             "stress_ng_switch":2702.625, "stress_ng_vecmath":2402.705}

plt.figure(figsize=(18,7))
plt.xticks(fontsize=13, rotation=270)
plt.yticks(fontsize=13)
plt.ylabel("Energy Consumption (in Joules)", fontsize=13) 

loc_s = np.arange(len(spectre_performance))+0.2 # Offsetting the tick-label location
loc_r = np.arange(len(stock))-0.2 # Offsetting the tick-label location
xtick_loc = list(loc_s) + list(loc_r)
xticks = list(spectre_performance.keys())

plt.bar(loc_s,list(spectre_performance.values()),color="green", width=0.35,label='Spectre OFF')
plt.bar(loc_r,list(stock.values()),color="red", width=0.35,label='Stock')
plt.xticks(xtick_loc, xticks, rotation=90, ha="right")
plt.tick_params(axis='x', which='minor', pad=15)
plt.legend(loc='upper right', prop={'size': 15})
plt.title('CPU Governor: Performance')
plt.savefig("euro_sys/spectre/energy_stock_spectre_performance.pdf", bbox_inches='tight')

# %%
mds={"apache":2760.555, "CB memcpy":2402.660, "CB memset":2324.850, "CB mixed":2375.910, "CB read":2154.095,
     "CB write":2302.795, "OS create_files":200.570, "OS create_processes":273.265, "OS create_threads":209.340,
     "OS launch_programs":328.530, "MC add":682.585, "MC append":621.495, "MC delete":464.740, "MC get":462.070,
     "MC prepend":626.215, "MC replace":601.610, "MC set":680.600, "OS mem_alloc":182.045,
     "netperf_tcp_maerts":3512.335, "netperf_tcp_rr":3398.150, "netperf_tcp_sendfile":3526.275,
     "netperf_tcp_stream":3383.400, "netperf_udp_rr":3555.050, "netperf_udp_stream":3516.170, "nginx":1742.385,
     "aes":2407.360, "blowfish":722.635, "camellia":2341.320, "cast":730.480, "dsa":2835.425, "ecdsa":1836.255,
     "ghash":777.555, "hmac":794.545, "idea":704.170, "rc4":779.210, "rc5":763.000, "rmd160":783.225, "seed":717.665,
     "sha1":797.220, "sha256":809.440, "sha512":823.795, "whirlpool":821.295,
     "stress_ng_cpu":2420.825, "stress_ng_fork":2547.430, "stress_ng_matrix":2582.950, "stress_ng_msg":2470.960,
     "stress_ng_sem":2234.080, "stress_ng_sock":2789.865, "stress_ng_switch":2648.770, "stress_ng_vecmath":2425.375}

plt.figure(figsize=(18,7))
plt.xticks(fontsize=13, rotation=270)
plt.yticks(fontsize=13)
plt.ylabel("Energy Consumption (in Joules)", fontsize=13) 

loc_s = np.arange(len(mds))+0.2 # Offsetting the tick-label location
loc_r = np.arange(len(stock))-0.2 # Offsetting the tick-label location
xtick_loc = list(loc_s) + list(loc_r)
xticks = list(mds.keys())

plt.bar(loc_s,list(mds.values()),color="green", width=0.35,label='MDS OFF')
plt.bar(loc_r,list(stock.values()),color="red", width=0.35,label='Stock')
plt.xticks(xtick_loc, xticks, rotation=90, ha="right")
plt.tick_params(axis='x', which='minor', pad=15)
plt.legend(loc='upper right', prop={'size': 12})
plt.savefig("euro_sys/energy_stock_mds.pdf", bbox_inches='tight')

# %%
mitigations_off={"apache":2592.710, "CB memcpy":2292.720, "CB memset":2328.060, "CB mixed":2370.200,
                 "CB read":2203.910, "CB write":2300.675, "OS create_files":191.625, "OS create_processes":261.195,
                 "OS create_threads":211.295, "OS launch_programs":342.510, "MC add":630.100, "MC append":555.800,
                 "MC delete":394.295, "MC get":415.195, "MC prepend":578.355, "MC replace":579.285,
                 "MC set":626.755, "OS mem_alloc":177.330, "netperf_tcp_maerts":3497.495,
                 "netperf_tcp_rr":3511.860, "netperf_tcp_sendfile":3475.325, "netperf_tcp_stream":3493.365,
                 "netperf_udp_rr":3552.395, "netperf_udp_stream":3538.750, "nginx":1755.945, "aes":2397.555,
                 "blowfish":712.725, "camellia":2321.330, "cast":705.885, "dsa":2887.640, "ecdsa":1854.330,
                 "ghash":781.765, "hmac":782.870, "idea":738.120, "rc4":746.955, "rc5":764.810, "rmd160":778.125,
                 "seed":724.945, "sha1":809.485, "sha256":786.705, "sha512":783.090, "whirlpool":794.720,
                 "stress_ng_cpu":2412.365, "stress_ng_fork":2571.830, "stress_ng_matrix":2604.115, "stress_ng_msg":2500.305,
                 "stress_ng_sem":2103.185, "stress_ng_sock":2702.995, "stress_ng_switch":2758.485, "stress_ng_vecmath":2266.495}
new_mitigations_off = {"apache":2366.635, "CB memcpy":2291.740, "CB memset":2324.775, "CB mixed":2322.395,
                       "CB read":2248.840, "CB write":2262.185, "OS create_files":202.420, 
                       "OS create_processes":263.525, "OS create_threads":227.370, "OS launch_programs":340.650, 
                       "MC add":508.205, "MC append":494.605, "MC delete":297.650, "MC get":295.725, 
                       "MC prepend":485.935, "MC replace":478.930, "MC set":539.235, "OS mem_alloc":179.635, 
                       "netperf_tcp_maerts":3443.460, "netperf_tcp_rr":3417.660, "netperf_tcp_sendfile":3445.455, 
                       "netperf_tcp_stream":3365.540, "netperf_udp_rr":3428.315, "netperf_udp_stream":3476.920, 
                       "nginx":1526.535, "aes":2393.225, "blowfish":717.390, "camellia":2313.020, "cast":720.390,
                       "dsa":2877.540, "ecdsa":1843.415, "ghash":771.630, "hmac":784.375, "idea":730.715,
                       "rc4":773.675, "rc5":772.355, "rmd160":791.845, "seed":715.070, "sha1":825.185,
                       "sha256":813.190, "sha512":815.215, "whirlpool":811.775,
                       "stress_ng_cpu":2342.345, "stress_ng_fork":2569.515, "stress_ng_matrix":2519.505,
                       "stress_ng_msg":2488.195, "stress_ng_sem":2177.430, "stress_ng_sock":2767.240,
                       "stress_ng_switch":2601.425, "stress_ng_vecmath":2392.155}

plt.figure(figsize=(18,7))
plt.xticks(fontsize=13, rotation=270)
plt.yticks(fontsize=13)
plt.ylabel("Energy Consumption (in Joules)", fontsize=13) 

loc_s = np.arange(len(new_mitigations_off))+0.2 # Offsetting the tick-label location
loc_r = np.arange(len(stock))-0.2 # Offsetting the tick-label location
xtick_loc = list(loc_s) + list(loc_r)
xticks = list(new_mitigations_off.keys())

plt.bar(loc_s,list(new_mitigations_off.values()),color="green", width=0.35,label='Mitigations OFF')
plt.bar(loc_r,list(stock.values()),color="red", width=0.35,label='Stock')
plt.xticks(xtick_loc, xticks, rotation=90, ha="right")
plt.tick_params(axis='x', which='minor', pad=15)
plt.legend(loc='upper right', prop={'size': 12})
plt.savefig("euro_sys/energy_stock_all_mitigations.pdf", bbox_inches='tight')

# %%
stock={"apache":2879.730, "CB memcpy":2470.385, "CB memset":2327.400, "CB mixed":2335.665, "CB read":2182.975,
       "CB write":2309.585, "OS create_files":188.245, "OS create_processes":275.330, "OS create_threads":211.320,
       "OS launch_programs":322.920, "MC add":682.755, "MC append":661.340, "MC delete":466.460, "MC get":464.350,
       "MC prepend":640.725, "MC replace":644.835, "MC set":684.005, "OS mem_alloc":192.920,
       "netperf_tcp_maerts":3290.570, "netperf_tcp_rr":3476.590, "netperf_tcp_sendfile":3515.900,
       "netperf_tcp_stream":3420.280, "netperf_udp_rr":3505.420, "netperf_udp_stream":3477.705, "nginx":1988.240}

meltdown_performance={"apache":2668.035, "CB memcpy":2380.720, "CB memset":2276.785, "CB mixed":2365.130, 
                      "CB read":2236.925, "CB write":2289.760, "OS create_files":194.240, 
                      "OS create_processes":266.965, "OS create_threads":225.695, "OS launch_programs":341.240, 
                      "MC add":677.205, "MC append":635.365, "MC delete":424.170, "MC get":405.115, 
                      "MC prepend":629.230, "MC replace":623.425, "MC set":654.585, "OS mem_alloc":167.440, 
                      "netperf_tcp_maerts":3497.845, "netperf_tcp_rr":3314.800, "netperf_tcp_sendfile":3526.425, 
                      "netperf_tcp_stream":3453.070, "netperf_udp_rr":3523.705, "netperf_udp_stream":3511.870, 
                      "nginx":1809.905}

spectre_performance={"apache":2561.035, "CB memcpy":2398.450, "CB memset":2269.085, "CB mixed":2386.640, 
             "CB read":2229.440, "CB write":2313.950, "OS create_files":196.530, "OS create_processes":272.890, 
             "OS create_threads":204.965, "OS launch_programs":321.650, "MC add":541.645, "MC append":535.090, 
             "MC delete":344.655, "MC get":356.875, "MC prepend":539.360, "MC replace":546.175, "MC set":566.770, 
             "OS mem_alloc":183.705, "netperf_tcp_maerts":3481.135, "netperf_tcp_rr":3515.085, 
             "netperf_tcp_sendfile":3520.250, "netperf_tcp_stream":3434.025, "netperf_udp_rr":3329.735,
             "netperf_udp_stream":3492.800, "nginx":1684.625}

mds={"apache":2760.555, "CB memcpy":2402.660, "CB memset":2324.850, "CB mixed":2375.910, "CB read":2154.095,
     "CB write":2302.795, "OS create_files":200.570, "OS create_processes":273.265, "OS create_threads":209.340,
     "OS launch_programs":328.530, "MC add":682.585, "MC append":621.495, "MC delete":464.740, "MC get":462.070,
     "MC prepend":626.215, "MC replace":601.610, "MC set":680.600, "OS mem_alloc":182.045,
     "netperf_tcp_maerts":3512.335, "netperf_tcp_rr":3398.150, "netperf_tcp_sendfile":3526.275,
     "netperf_tcp_stream":3383.400, "netperf_udp_rr":3555.050, "netperf_udp_stream":3516.170, "nginx":1742.385}

mitigations_off_performance = {"apache":2366.635, "CB memcpy":2291.740, "CB memset":2324.775, "CB mixed":2322.395,
                       "CB read":2248.840, "CB write":2262.185, "OS create_files":202.420, 
                       "OS create_processes":263.525, "OS create_threads":227.370, "OS launch_programs":340.650, 
                       "MC add":508.205, "MC append":494.605, "MC delete":297.650, "MC get":295.725, 
                       "MC prepend":485.935, "MC replace":478.930, "MC set":539.235, "OS mem_alloc":179.635, 
                       "netperf_tcp_maerts":3443.460, "netperf_tcp_rr":3417.660, "netperf_tcp_sendfile":3445.455, 
                       "netperf_tcp_stream":3365.540, "netperf_udp_rr":3428.315, "netperf_udp_stream":3476.920, 
                       "nginx":1526.535}

plt.figure(figsize=(22,7))
plt.xticks(fontsize=13, rotation=270)
plt.yticks(fontsize=13)
plt.ylabel("Energy Consumption (in Joules)", fontsize=13) 

loc_l = np.arange(len(mitigations_off_performance))+0.6
loc_p = np.arange(len(mds))+0.3
loc_t = np.arange(len(spectre_performance))-0.0
loc_s = np.arange(len(meltdown_performance))-0.3 # Offsetting the tick-label location
loc_r = np.arange(len(stock))-0.6 # Offsetting the tick-label location

xtick_loc = list(loc_s) + list(loc_r) + list(loc_t) + list(loc_p) + list(loc_l)
xticks = list(meltdown_performance.keys())
ax = plt.axes()
ax.xaxis.set_major_locator(ticker.MultipleLocator(5))

plt.bar(loc_l,list(spectre_performance.values()),color="purple", width=0.25,label='Mitigations OFF')
plt.bar(loc_p,list(meltdown_performance.values()),color="orange", width=0.25,label='MDS OFF')
plt.bar(loc_t,list(spectre_performance.values()),color="blue", width=0.25,label='Spectre OFF')
plt.bar(loc_s,list(meltdown_performance.values()),color="green", width=0.25,label='Meltdown OFF')
plt.bar(loc_r,list(stock.values()),color="red", width=0.25,label='Stock')
plt.xticks(xtick_loc, xticks, rotation=90, ha="right")
plt.tick_params(axis='x', which='minor', pad=15)
plt.legend(loc='upper right', prop={'size': 12})
plt.savefig("euro_sys/energy_stock_meltdown_spectre.pdf", bbox_inches='tight')

# %%
categorical_1 = ["apache", "CB memcpy", "CB memset", "CB mixed", "CB read", "CB write"]
colors = ['red', 'green', 'blue', 'orange', 'purple']
numerical = [[2879.730, 2470.385, 2327.400, 2335.665, 2182.975, 2309.585],
             [2668.035, 2380.720, 2276.785, 2365.130, 2236.925, 2289.760],
             [2561.035, 2398.450, 2269.085, 2386.640, 2229.440, 2313.950],
             [2760.555, 2402.660, 2324.850, 2375.910, 2154.095, 2302.795],
             [2592.710, 2292.720, 2328.060, 2370.200, 2203.910, 2300.675]]


categorical_1 = ["apache", "CB memcpy", "CB memset", "CB mixed", "CB read"]
colors        = ['green', 'red', 'blue', 'orange', 'purple']
numerical = [[2879.730, 2470.385, 2327.400, 2335.665, 2182.975],
             [2668.035, 2380.720, 2276.785, 2365.130, 2236.925],
             [2561.035, 2398.450, 2269.085, 2386.640, 2229.440],
             [2760.555, 2402.660, 2324.850, 2375.910, 2154.095],
             [2592.710, 2292.720, 2328.060, 2370.200, 2203.910]]
number_groups = len(categorical_1) 
bin_width = 1.0/(number_groups+1)
fig, ax = plt.subplots(figsize=(6,6))
for i in range(number_groups):
    ax.bar(x=np.arange(len(categorical_1)) + i*bin_width, 
           height=numerical[i],
           width=bin_width,
           color=colors[i],
           align='center')
ax.set_xticks(np.arange(len(categorical_1)) + number_groups/(2*(number_groups+1)))

# number_groups/(2*(number_groups+1)): offset of xticklabel
ax.set_xticklabels(categorical_1)
ax.legend(categorical_1, facecolor='w')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-114-0d711cb8c556> in <module>
#      24            color=colors[i],
#      25            align='center',
# ---> 26            rotate=90)
#      27 ax.set_xticks(np.arange(len(categorical_1)) + number_groups/(2*(number_groups+1)))
#      28
#
# /usr/local/lib64/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /usr/local/lib64/python3.6/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2296                 label='_nolegend_',
#    2297                 )
# ...

# %%
stock={"apache":44.50, "CB memcpy":52.35, "CB memset":50.05, "CB mixed":50.35, "CB read":52.00, "CB write":50.05,
       "OS create_files":5.00, "OS create_processes":5.00, "OS create_threads":5.00, "OS launch_programs":5.00,
       "MC add":14.05, "MC append":13.75, "MC delete":9.00, "MC get":9.00, "MC prepend":13.40, "MC replace":13.40,
       "MC set":14.00, "OS mem_alloc":5.00, "netperf_tcp_maerts":60.00, "netperf_tcp_rr":60.00,
       "netperf_tcp_sendfile":60.00, "netperf_tcp_stream":60.00, "netperf_udp_rr":60.00,
       "netperf_udp_stream":60.00, "nginx":35.35, "aes":54.00, "blowfish":18.00, "camellia":54.00, "cast":18.00,
       "dsa":60.00, "ecdsa":40.00, "ghash":18.00, "hmac":18.00, "idea":18.00, "rc4":18.00, "rc5":18.00,
       "rmd160":18.00, "seed":18.00, "sha1":18.00, "sha256":18.00, "sha512":18.00, "whirlpool":18.00,
       "stress_ng_cpu":30.00, "stress_ng_fork":30.00, "stress_ng_matrix":30.00, "stress_ng_msg":30.00,
       "stress_ng_sem":30.00, "stress_ng_sock":30.00, "stress_ng_switch":30.00, "stress_ng_vecmath":30.00}

meltdown_ondemand={"apache":42.85, "CB memcpy":51.95, "CB memset":50.00, "CB mixed":50.00, "CB read":52.00, 
                   "CB write":50.00, "OS create_files":5.00, "OS create_processes":5.00, "OS create_threads":5.00,
                   "OS launch_programs":5.00, "MC add":20.95, "MC append":20.65, "MC delete":9.00, "MC get":9.00,
                   "MC prepend":20.60, "MC replace":20.55, "MC set":21.00, "OS mem_alloc":5.00,
                   "netperf_tcp_maerts":60.00, "netperf_tcp_rr":60.00, "netperf_tcp_sendfile":60.00,
                   "netperf_tcp_stream":60.00, "netperf_udp_rr":60.00, "netperf_udp_stream":60.00, "nginx":34.65,
                   "aes":54.00, "blowfish":18.00, "camellia":54.00, "cast":18.00, "dsa":60.00, "ecdsa":40.00,
                   "ghash":18.00, "hmac":18.00, "idea":18.00, "rc4":18.00, "rc5":18.00, "rmd160":18.00, "seed":18.00,
                   "sha1":18.00, "sha256":18.00, "sha512":18.00, "whirlpool":18.00, "stress_ng_cpu":30.00, 
                   "stress_ng_fork":30.00, "stress_ng_matrix":30.00, "stress_ng_msg":30.00, "stress_ng_sem":30.00, 
                   "stress_ng_sock":30.00, "stress_ng_switch":30.00, "stress_ng_vecmath":30.00}

meltdown_performance={"apache":42.05, "CB memcpy":52.05, "CB memset":50.00, "CB mixed":50.00, "CB read":52.00,
                      "CB write":50.00, "OS create_files":5.00, "OS create_processes":5.00, 
                      "OS create_threads":5.00, "OS launch_programs":5.00, "MC add":13.90, "MC append":13.00, 
                      "MC delete":8.10, "MC get":8.00, "MC prepend":13.00, "MC replace":13.00, "MC set":13.65, 
                      "OS mem_alloc":5.00, "netperf_tcp_maerts":60.00, "netperf_tcp_rr":60.00, 
                      "netperf_tcp_sendfile":60.00, "netperf_tcp_stream":60.00, "netperf_udp_rr":60.00, 
                      "netperf_udp_stream":60.00, "nginx":33.35, "aes":54.00, "blowfish":18.00, "camellia":54.00, 
                      "cast":18.00, "dsa":60.00, "ecdsa":40.00, "ghash":18.00, "hmac":18.00, "idea":18.00, 
                      "rc4":18.00, "rc5":18.00, "rmd160":18.00, "seed":18.00, "sha1":18.00, "sha256":18.00, 
                      "sha512":18.00, "whirlpool":18.00, "stress_ng_cpu":30.00, 
                      "stress_ng_fork":30.00, "stress_ng_matrix":30.00, "stress_ng_msg":30.00, 
                      "stress_ng_sem":30.00, "stress_ng_sock":30.00, "stress_ng_switch":30.00, 
                      "stress_ng_vecmath":30.00}

plt.figure(figsize=(18,7))
plt.xticks(fontsize=13, rotation=270)
plt.yticks(fontsize=13)
plt.ylabel("Execution Time (in Seconds)", fontsize=13) 

loc_s = np.arange(len(meltdown_performance))+0.2 # Offsetting the tick-label location
loc_r = np.arange(len(stock))-0.2 # Offsetting the tick-label location
xtick_loc = list(loc_s) + list(loc_r)
xticks = list(meltdown_performance.keys())

plt.bar(loc_s,list(meltdown_performance.values()),color="blue", width=0.35,label='Metldown OFF')
plt.bar(loc_r,list(stock.values()),color="red", width=0.35,label='Stock')
plt.xticks(xtick_loc, xticks, rotation=90, ha="right")
plt.tick_params(axis='x', which='minor', pad=15)
plt.legend(loc='upper right', prop={'size': 15})
plt.title('CPU Governor: Performance')
plt.savefig("euro_sys/meltdown/run_time_stock_meltdown_performance.pdf", bbox_inches='tight')

# %%
spectre_ondemand={"apache":45.70, "CB memcpy":52.40, "CB memset":50.05, "CB mixed":50.20, "CB read":52.00,
          "CB write":50.15, "OS create_files":5.00, "OS create_processes":5.00, "OS create_threads":5.00,
          "OS launch_programs":5.00, "MC add":21.00, "MC append":21.45, "MC delete":9.00, "MC get":9.00,
          "MC prepend":21.30, "MC replace":21.05, "MC set":21.05, "OS mem_alloc":5.00, "netperf_tcp_maerts":60.00,
          "netperf_tcp_rr":60.00, "netperf_tcp_sendfile":60.00, "netperf_tcp_stream":60.00,
          "netperf_udp_rr":60.00, "netperf_udp_stream":60.00, "nginx":36.85, "aes":54.00, "blowfish":18.00,
          "camellia":54.00, "cast":18.00, "dsa":60.00, "ecdsa":40.00, "ghash":18.00, "hmac":18.00, "idea":18.00,
          "rc4":18.00, "rc5":18.00, "rmd160":18.00, "seed":18.00, "sha1":18.00, "sha256":18.00, "sha512":18.00,
          "whirlpool":18.00, "stress_ng_cpu":30.00, "stress_ng_fork":30.00,
          "stress_ng_matrix":30.00, "stress_ng_msg":30.00, "stress_ng_sem":30.00, "stress_ng_sock":30.00,
          "stress_ng_switch":30.00, "stress_ng_vecmath":30.00}

spectre_performance={"apache":39.10, "CB memcpy":52.30, "CB memset":50.20, "CB mixed":50.15, "CB read":52.00, 
                     "CB write":50.10, "OS create_files":5.00, "OS create_processes":5.00, "OS create_threads":5.00,
                     "OS launch_programs":5.00, "MC add":11.45, "MC append":11.00, "MC delete":7.00, "MC get":7.00,
                     "MC prepend":11.00, "MC replace":11.00, "MC set":11.45, "OS mem_alloc":5.00,
                     "netperf_tcp_maerts":60.00, "netperf_tcp_rr":60.00, "netperf_tcp_sendfile":60.00, 
                     "netperf_tcp_stream":60.00, "netperf_udp_rr":60.00, "netperf_udp_stream":60.00, "nginx":30.15,
                     "aes":54.00, "blowfish":18.00, "camellia":54.00, "cast":18.00, "dsa":60.00, "ecdsa":40.00,
                     "ghash":18.00, "hmac":18.00, "idea":18.00, "rc4":18.00, "rc5":18.00, "rmd160":18.00,
                     "seed":18.00, "sha1":18.00, "sha256":18.00, "sha512":18.00, "whirlpool":18.00,
                     "stress_ng_cpu":30.00, "stress_ng_fork":30.00, "stress_ng_matrix":30.00, 
                     "stress_ng_msg":30.00, "stress_ng_sem":30.00, "stress_ng_sock":30.00, 
                     "stress_ng_switch":30.00, "stress_ng_vecmath":30.00}

plt.figure(figsize=(18,7))
plt.xticks(fontsize=13, rotation=270)
plt.yticks(fontsize=13)
plt.ylabel("Execution Time (in Seconds)", fontsize=13) 

loc_s = np.arange(len(spectre_performance))+0.2 # Offsetting the tick-label location
loc_r = np.arange(len(stock))-0.2 # Offsetting the tick-label location
xtick_loc = list(loc_s) + list(loc_r)
xticks = list(spectre_performance.keys())

plt.bar(loc_s,list(spectre_performance.values()),color="blue", width=0.35,label='Spectre OFF')
plt.bar(loc_r,list(stock.values()),color="red", width=0.35,label='Stock')
plt.xticks(xtick_loc, xticks, rotation=90, ha="right")
plt.tick_params(axis='x', which='minor', pad=15)
plt.legend(loc='upper right', prop={'size': 15})
plt.title('CPU Governor: Performance')
plt.savefig("euro_sys/spectre/run_time_stock_spectre_performance.pdf", bbox_inches='tight')

# %%
mds={"apache":42.80, "CB memcpy":52.25, "CB memset":50.00, "CB mixed":50.00, "CB read":52.00, "CB write":50.00,
     "OS create_files":5.00, "OS create_processes":5.00, "OS create_threads":5.00, "OS launch_programs":5.00,
     "MC add":14.00, "MC append":13.00, "MC delete":9.00, "MC get":9.00, "MC prepend":13.00, "MC replace":13.00,
     "MC set":14.00, "OS mem_alloc":5.00, "netperf_tcp_maerts":60.00, "netperf_tcp_rr":60.00,
     "netperf_tcp_sendfile":60.00, "netperf_tcp_stream":60.00, "netperf_udp_rr":60.00, "netperf_udp_stream":60.00,
     "nginx":32.70, "aes":54.00, "blowfish":18.00, "camellia":54.00, "cast":18.00, "dsa":60.00, "ecdsa":40.00,
     "ghash":18.00, "hmac":18.00, "idea":18.00, "rc4":18.00, "rc5":18.00, "rmd160":18.00, "seed":18.00, "sha1":18.00,
     "sha256":18.00, "sha512":18.00, "whirlpool":18.00, "stress_ng_cpu":30.00,
     "stress_ng_fork":30.00, "stress_ng_matrix":30.00, "stress_ng_msg":30.00, "stress_ng_sem":30.00,
     "stress_ng_sock":30.00, "stress_ng_switch":30.00, "stress_ng_vecmath":30.00}

plt.figure(figsize=(18,7))
plt.xticks(fontsize=13, rotation=270)
plt.yticks(fontsize=13)
plt.ylabel("Execution Time (in Seconds)", fontsize=13) 

loc_s = np.arange(len(mds))+0.2 # Offsetting the tick-label location
loc_r = np.arange(len(stock))-0.2 # Offsetting the tick-label location
xtick_loc = list(loc_s) + list(loc_r)
xticks = list(mds.keys())

plt.bar(loc_s,list(mds.values()),color="blue", width=0.35,label='MDS OFF')
plt.bar(loc_r,list(stock.values()),color="red", width=0.35,label='Stock')
plt.xticks(xtick_loc, xticks, rotation=90, ha="right")
plt.tick_params(axis='x', which='minor', pad=15)
plt.legend(loc='upper right', prop={'size': 12})
plt.savefig("euro_sys/performance_stock_mds.pdf", bbox_inches='tight')

# %%
mitigations_off = {"apache":40.10, "CB memcpy":51.50, "CB memset":50.00, "CB mixed":50.00, "CB read":52.00,
                   "CB write":50.00, "OS create_files":5.00, "OS create_processes":5.00, "OS create_threads":5.00,
                   "OS launch_programs":5.00, "MC add":13.00, "MC append":12.05, "MC delete":8.00, "MC get":8.00,
                   "MC prepend":12.00, "MC replace":12.00, "MC set":13.00, "OS mem_alloc":5.00,
                   "netperf_tcp_maerts":60.00, "netperf_tcp_rr":60.00, "netperf_tcp_sendfile":60.00,
                   "netperf_tcp_stream":60.00, "netperf_udp_rr":60.00, "netperf_udp_stream":60.00, "nginx":31.50,
                   "aes":54.00, "blowfish":18.00, "camellia":54.00, "cast":18.00, "dsa":60.00, "ecdsa":40.00,
                   "ghash":18.00, "hmac":18.00, "idea":18.00, "rc4":18.00, "rc5":18.00, "rmd160":18.00, "seed":18.00,
                   "sha1":18.00, "sha256":18.00, "sha512":18.00, "whirlpool":18.00, "stress_ng_cpu":30.00,
                   "stress_ng_fork":30.00, "stress_ng_matrix":30.00, "stress_ng_msg":30.00, "stress_ng_sem":30.00,
                   "stress_ng_sock":30.00, "stress_ng_switch":30.00, "stress_ng_vecmath":30.00}
new_mitigations_off = {"apache":36.00, "CB memcpy":51.30, "CB memset":50.00, "CB mixed":50.00, "CB read":52.00, 
                       "CB write":50.00, "OS create_files":5.00, "OS create_processes":5.00, 
                       "OS create_threads":5.00, "OS launch_programs":5.00, "MC add":10.60, "MC append":10.00, 
                       "MC delete":6.00, "MC get":6.00, "MC prepend":10.00, "MC replace":10.00, "MC set":10.85, 
                       "OS mem_alloc":5.00, "netperf_tcp_maerts":60.00, "netperf_tcp_rr":60.00, 
                       "netperf_tcp_sendfile":60.00, "netperf_tcp_stream":60.00, "netperf_udp_rr":60.00, 
                       "netperf_udp_stream":60.00, "nginx":27.00, "aes":54.00, "blowfish":18.00, "camellia":54.00, 
                       "cast":18.00, "dsa":60.00, "ecdsa":40.00, "ghash":18.00, "hmac":18.00, "idea":18.00, 
                       "rc4":18.00, "rc5":18.00, "rmd160":18.00, "seed":18.00, "sha1":18.00, "sha256":18.00, 
                       "sha512":18.00, "whirlpool":18.00, "stress_ng_cpu":30.00, 
                       "stress_ng_fork":30.00, "stress_ng_matrix":30.00, "stress_ng_msg":30.00, 
                       "stress_ng_sem":30.00, "stress_ng_sock":30.00, "stress_ng_switch":30.00, 
                       "stress_ng_vecmath":30.00}

plt.figure(figsize=(18,7))
plt.xticks(fontsize=13, rotation=270)
plt.yticks(fontsize=13)
plt.ylabel("Execution Time (in Seconds)", fontsize=13) 

loc_s = np.arange(len(new_mitigations_off))+0.2 # Offsetting the tick-label location
loc_r = np.arange(len(stock))-0.2 # Offsetting the tick-label location
xtick_loc = list(loc_s) + list(loc_r)
xticks = list(new_mitigations_off.keys())

plt.bar(loc_s,list(new_mitigations_off.values()),color="blue", width=0.35,label='MDS OFF')
plt.bar(loc_r,list(stock.values()),color="red", width=0.35,label='Stock')
plt.xticks(xtick_loc, xticks, rotation=90, ha="right")
plt.tick_params(axis='x', which='minor', pad=15)
plt.legend(loc='upper right', prop={'size': 12})
plt.savefig("euro_sys/performance_stock_all_mitigations.pdf", bbox_inches='tight')
